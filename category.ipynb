# %% [markdown]
# boiler heater
# thermostat
# supply
# meter
# account
# payment
# struggling to pay

# %%
import pandas as pd

# %%
df1 = pd.DataFrame({'Questions': [
        'I need to contact someone about my boiler',
        'I need to contact someone about my storage heater',
        'I need to contact someone about my insulation',
        'I need to contact someone about my heat pump',
        'Faulty or damaged in-home display thermostat',
        'I have a problem with my HeatSmart or Netamo smart thermostat',
        'Electricity supply',
        'Gas supply',
        'Neither, I need a new supply',
        'My top-up card',
        'Topping up',
        'Emergency credit',
        'Disconnection (no energy supply)',
        'Faulty or damaged meter',
        'Faulty or damaged in-home display',
        'Meter readings',
        'Help accessing MyAccount',
        'Change my personal or account details'
        'I can\'t view my bill in MyAccount',
        'I\'ve downloaded the EDF app for my Apple device, but it keeps crashing',
        'Help with a payment that\'s due',
        'Help with a recent payment',
        'I want a refund of my account credit',
        'Help with the Energy Bills Support Scheme',
        'Reduce energy costs',
        'Maximise household income',
        'Paying my bills',
        'Managing my energy as I have an illness, disability, or mental health issue',
        'General debt advice',
        'live with a child under five years old',
        'live alone or with others and have reached state pension age',
        'live alone or with others and are disabled or chronically ill',
        'live with others who have reached state pension age or are disabled chronically ill or under 18 years old', 
        'medicine refrigerator problem',
        'elderly have problem reading their bills',
        'elderly have problem with hearing on the phone',
        'elderly have problem with using electronic payments'
        ]
                   })
        

df2 = pd.DataFrame({'Category':[
            'boiler heater','boiler heater','boiler heater','boiler heater',
             'thermostat','thermostat',
             'supply','supply','supply',
             'meter','meter','meter','meter','meter','meter','meter','meter',
             'account','account','account','account',
             'payment','payment','payment','payment',
             'struggling to pay','struggling to pay','struggling to pay','struggling to pay','struggling to pay',
            'high risk','high risk','high risk','high risk','high risk','high risk','high risk','high risk'
            ]
                   })

# %%
df = pd.concat([df2,df1], axis=1)

# %%
df
# Out:
#              Category                                          Questions
# 0       boiler heater          I need to contact someone about my boiler
# 1       boiler heater  I need to contact someone about my storage heater
# 2       boiler heater      I need to contact someone about my insulation
# 3       boiler heater       I need to contact someone about my heat pump
# 4          thermostat       Faulty or damaged in-home display thermostat
# 5          thermostat  I have a problem with my HeatSmart or Netamo s...
# 6              supply                                 Electricity supply
# 7              supply                                         Gas supply
# 8              supply                       Neither, I need a new supply
# 9               meter                                     My top-up card
# 10              meter                                         Topping up
# 11              meter                                   Emergency credit
# 12              meter                   Disconnection (no energy supply)
# 13              meter                            Faulty or damaged meter
# 14              meter                  Faulty or damaged in-home display
# 15              meter                                     Meter readings
# 16              meter                           Help accessing MyAccount
# 17            account  Change my personal or account detailsI can't v...
# 18            account  I've downloaded the EDF app for my Apple devic...
# 19            account                     Help with a payment that's due
# 20            account                         Help with a recent payment
# 21            payment               I want a refund of my account credit
# 22            payment          Help with the Energy Bills Support Scheme
# 23            payment                                Reduce energy costs
# 24            payment                          Maximise household income
# 25  struggling to pay                                    Paying my bills
# 26  struggling to pay  Managing my energy as I have an illness, disab...
# 27  struggling to pay                                General debt advice
# 28  struggling to pay             live with a child under five years old
# 29  struggling to pay  live alone or with others and have reached sta...
# 30          high risk  live alone or with others and are disabled or ...
# 31          high risk  live with others who have reached state pensio...
# 32          high risk                      medicine refrigerator problem
# 33          high risk           elderly have problem reading their bills
# 34          high risk     elderly have problem with hearing on the phone
# 35          high risk  elderly have problem with using electronic pay...
# 36          high risk                                                NaN
# 37          high risk                                                NaN
